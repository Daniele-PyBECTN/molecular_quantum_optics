# %%
# %%
# Jupyter Notebook cell 1 — Imports
import numpy as np
import pandas as pd

# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "v2/202512_power_scan.csv"

# Read the CSV file using pandas
data = pd.read_csv(file_path)

# Display the first few rows to verify
display(data.head())

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
Fluo_pow       = data["A"].to_numpy()
FWHM_pow       = data["fwhm"].to_numpy()
I_pow       = data["intensity"].to_numpy()
S_pow    = data["S"].to_numpy()


# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("Fluo:", Fluo_pow.shape, "→", Fluo_pow[:5])
print("FWHM_pow:", FWHM_pow.shape, "→", FWHM_pow[:5])
print("I:", I_pow.shape, "→", I_pow[:5])
print("S:", S_pow.shape, "→", S_pow[:5])
# Out:
#             A          fwhm  intensity         S
# 0  300.077240  9.946400e+07   0.320397  0.049505
# 1  305.815098  1.067719e+08   0.320397  0.050500
# 2  337.995382  6.795428e+07   0.320397  0.056112
# 3  132.560962  1.108078e+08   0.091542  0.021281
# 4  171.386444  6.673294e+07   0.091542  0.027687
# Fluo: (56,) → [300.07724022 305.81509767 337.99538171 132.56096206 171.38644418]
# FWHM_pow: (56,) → [9.94639960e+07 1.06771883e+08 6.79542836e+07 1.10807840e+08
#  6.67329400e+07]
# I: (56,) → [0.32039682 0.32039682 0.32039682 0.09154195 0.09154195]
# S: (56,) → [0.04950532 0.05049973 0.05611189 0.02128115 0.02768671]

# %%
# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "S_parameter_vs_temp.csv"

# Read the CSV file using pandas
data = pd.read_csv(file_path)

# Display the first few rows to verify
display(data.head())

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
T_pow2       = data["Temperature [K]"].to_numpy()
I_pow2       = data["Intensity [W/cm²]"].to_numpy()
S_pow2       = data["S"].to_numpy()
FWHM_pow2    = data["FWHM [Hz]"].to_numpy()
Gam_pow2 = data["FWHM deph + FWHM0 [Hz]"].to_numpy()
Fluo_pow2    = data["Fluorescence [cps]"].to_numpy()

# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("T:", T_pow2.shape, "→", T_pow2[:5])
print("I:", I_pow2.shape, "→", I_pow2[:5])
print("S:", S_pow2.shape, "→", S_pow2[:5])
print("FWHM:", FWHM_pow2.shape, "→", FWHM_pow2[:5])
print("Gam_tot:", Gam_pow2.shape, "→", Gam_pow2[:5])
print("Fluo:", Fluo_pow2.shape, "→", Fluo_pow2[:5])
# Out:
#    Temperature [K]  Intensity [W/cm²]         S     FWHM [Hz]  \
# 0         4.731820           0.428243  0.108321  2.535635e+08
# 1         4.777749           0.428243  0.123954  2.635728e+08
# 2         4.490514           0.428243  0.100211  2.133204e+08
# 3         5.075639           0.856485  0.225183  3.367827e+08
# 4         4.551905           1.712970  0.394787  2.508496e+08
#
#    FWHM deph + FWHM0 [Hz]  Fluorescence [cps]
# 0            2.408540e+08        15550.338565
# 1            2.486144e+08        17547.096787
# 2            2.033736e+08        14492.044091
# 3            3.042631e+08        29243.322029
# 4            2.124025e+08        45034.647029
# T: (49,) → [4.73181998 4.77774867 4.49051393 5.07563945 4.55190483]
# I: (49,) → [0.42824258 0.42824258 0.42824258 0.85648516 1.71297031]
# S: (49,) → [0.10832125 0.12395445 0.10021059 0.22518313 0.39478694]
# FWHM: (49,) → [2.53563457e+08 2.63572818e+08 2.13320427e+08 3.36782713e+08
#  2.50849642e+08]
# Gam_tot: (49,) → [2.40853984e+08 2.48614391e+08 2.03373581e+08 3.04263100e+08
#  2.12402464e+08]
# Fluo: (49,) → [15550.33856457 17547.09678679 14492.04409057 29243.32202877
#  45034.64702943]

# %%
Rinfty = np.amax(Fluo_pow)*1.005
print(Rinfty)
Gam_pow = FWHM_pow/(1+S_pow)**.5

Rinfty2 = np.amax(Fluo_pow2)*1.005
print(Rinfty2)
# Out:
# 6361.592008367916
# 159107.942923358

# %%
# %%
# (Optional) Example plot with color-coded markers by intensity I (log-scale colormap)
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# Compute Cross_AS
Cross_AS = Fluo_pow #/ I_pow * Gam_pow / 40e6
Cross_AS = Cross_AS / np.amax(Cross_AS)

# Avoid zero or negative values for log normalization
I_pos = np.clip(Gam_pow, np.min(Gam_pow[Gam_pow > 0]), None)

plt.figure(figsize=(6, 4))

# Compute Cross_AS
Cross_AS2 = Fluo_pow2 #/ I_pow * Gam_pow / 40e6
Cross_AS2 = Cross_AS2 / np.amax(Cross_AS2)
# Avoid zero or negative values for log normalization
I_pos2 = np.clip(Gam_pow2, np.min(Gam_pow2[Gam_pow2 > 0]), None)
sc2 = plt.scatter(
    I_pow2, Cross_AS2,
    c=T_pow2,
    cmap='hot',
    vmin=3., 
    vmax=np.max(T_pow2),
    s=60,
    edgecolor='k',
    marker='o',
    label="Old"
)

# Scatter plot with log-scale color normalization
sc = plt.scatter(
    I_pow, Cross_AS,
    c=(I_pos*0+3.7),
    cmap='hot',
    vmin=3., 
    vmax=np.max(T_pow2),
    s=60,
    alpha=0.7,
    edgecolor='k',
    marker='x',
    label="New"
)





# Add colorbar
cbar = plt.colorbar(sc2)
cbar.set_label("Intensity I (log scale)")

plt.xlabel("Intensity")
plt.ylabel("Cross_AS (normalized)")
plt.xscale('log')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/y4/dpq6l9fj2kv9z0prq_6_pyy00000gn/T/ipykernel_45714/3229867096.py:33: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   sc = plt.scatter(

# %%
plt.plot(Gam_pow, I_pow, marker='s', linestyle='none')
plt.xscale('log')

# %%
plt.plot(I_pow, FWHM_pow, marker='s', linestyle='none')
plt.plot(I_pow, Gam_pow, marker='s', linestyle='none')

plt.plot(I_pow2, FWHM_pow2/4, marker='o', linestyle='none')
plt.plot(I_pow2, Gam_pow2/4, marker='o', linestyle='none')

plt.xscale('log')
plt.yscale('log')
plt.xlim(1e1,1e5)
plt.ylim(1e7,1e11)
plt.grid()

# %%
plt.plot(I_pow**.5, Gam_pow*1e-9, marker='s', linestyle='none')
plt.plot(I_pow2**.5, Gam_pow2*1e-9, marker='o', linestyle='none')
#plt.xscale('log')
#plt.yscale('log')
plt.ylim(0,10)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "v2/202512_temperature_scan.csv"

# Read the CSV file using pandas
data = pd.read_csv(file_path)

# Display the first few rows to verify
display(data.head())

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
T_temp1       = data["temperature"].to_numpy()
I_temp1       = data["intensity"].to_numpy()
S_temp1       = data["S"].to_numpy()
FWHM_temp1    = data["fwhm"].to_numpy()
Fluo_temp1    = data["A"].to_numpy()

# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("T:", T_temp1.shape, "→", T_temp1[:5])
print("I:", I_temp1.shape, "→", I_temp1[:5])
print("S:", S_temp1.shape, "→", S_temp1[:5])
print("FWHM:", FWHM_temp1.shape, "→", FWHM_temp1[:5])
print("Fluo:", Fluo_temp1.shape, "→", Fluo_temp1[:5])

Gam_temp1 = FWHM_temp1/(1+S_temp1)**.5
# Out:
#              A          fwhm  temperature  intensity         S
# 0  4179.364970  1.385442e+08       4.1660   6.865646  1.915183
# 1  3906.119749  1.616217e+08       4.1205   6.865646  1.590781
# 2  3641.696052  1.315464e+08       4.0290   6.865646  1.338910
# 3  3663.892454  1.489359e+08       4.2720   6.865646  1.358154
# 4  3881.023434  1.091647e+08       4.1930   6.865646  1.564570
# T: (86,) → [4.166  4.1205 4.029  4.272  4.193 ]
# I: (86,) → [6.8656462 6.8656462 6.8656462 6.8656462 6.8656462]
# S: (86,) → [1.91518339 1.59078146 1.33891006 1.35815438 1.56457011]
# FWHM: (86,) → [1.38544179e+08 1.61621667e+08 1.31546424e+08 1.48935888e+08
#  1.09164720e+08]
# Fluo: (86,) → [4179.36497049 3906.11974885 3641.69605187 3663.89245435 3881.02343436]

# %%
# S in the data set has an offset artificial and it's S+1!!!
# (Optional) Example plot with color-coded markers by intensity I (log-scale colormap)
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# Compute Cross_AS
#Cross_temp1 = S_temp1 * FWHM_temp1/(1+S_temp1)**.5/I_temp1
Cross_temp1 = S_temp1/I_temp1
Cross_temp1 = Cross_temp1 / np.amax(Cross_temp1)


# Avoid zero or negative values for log normalization
I_postemp1 = np.clip(I_temp1, np.min(I_temp1[I_temp1 > 0]), None)

plt.figure(figsize=(6, 4))

# Scatter plot with log-scale color normalization
sctemp1 = plt.scatter(
    T_temp1, Cross_temp1,
    c=I_postemp1,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_postemp1), vmax=np.max(I_postemp1)),
    s=60,
    edgecolor='k',
    label="Cross_AS vs T"
)

GGT1 = 1/(FWHM_temp1/(1+S_temp1))
GGT1 = GGT1/np.amax(GGT1)
sctemp2 = plt.scatter(
    T_temp1, GGT1,
    c=I_postemp1,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_postemp1), vmax=np.max(I_postemp1)),
    s=30,
    edgecolor='k',
    marker='s',
    label="Cross_AS vs T"
)

# Add colorbar
cbar = plt.colorbar(sctemp1)
cbar.set_label("Intensity I (log scale)")

plt.xlabel("Temperature T")
plt.ylabel("Cross_temp (normalized)")
plt.yscale('log')
#plt.ylim(0,0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "S_parameter_vs_temp_temp_scan.csv"

# Read the CSV file using pandas
data = pd.read_csv(file_path)

# Display the first few rows to verify
display(data.head())

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
T_temp2       = data["Temperature [K]"].to_numpy()
I_temp2       = data["Intensity [W/cm²]"].to_numpy()
S_temp2       = data["S"].to_numpy()
FWHM_temp2    = data["FWHM [Hz]"].to_numpy()
Gam_tot_temp2 = data["FWHM deph + FWHM0 [Hz]"].to_numpy()
Fluo_temp2    = data["Fluorescence [cps]"].to_numpy()

# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("T:", T_temp2.shape, "→", T_temp2[:5])
print("I:", I_temp2.shape, "→", I_temp2[:5])
print("S:", S_temp2.shape, "→", S_temp2[:5])
print("FWHM:", FWHM_temp2.shape, "→", FWHM_temp2[:5])
print("Gam_tot:", Gam_tot_temp2.shape, "→", Gam_tot_temp2[:5])
print("Fluo:", Fluo_temp2.shape, "→", Fluo_temp2[:5])
# Out:
#    Temperature [K]  Intensity [W/cm²]         S     FWHM [Hz]  \
# 0         4.165629           2.288549  2.002149  1.547998e+08
# 1         4.089000           2.288549  2.034346  1.582756e+08
# 2         3.980500           2.288549  2.153754  1.509551e+08
# 3         4.213500           2.288549  1.995608  1.647924e+08
# 4         4.130500           2.288549  2.006077  1.632949e+08
#
#    FWHM deph + FWHM0 [Hz]  Fluorescence [cps]
# 0            8.934172e+07        77863.836446
# 1            9.086182e+07        79093.525118
# 2            8.500291e+07        83333.011420
# 3            9.521266e+07        77609.181995
# 4            9.418303e+07        78015.954792
# T: (175,) → [4.16562857 4.089      3.9805     4.2135     4.1305    ]
# I: (175,) → [2.28854873 2.28854873 2.28854873 2.28854873 2.28854873]
# S: (175,) → [2.00214896 2.03434604 2.15375429 1.99560828 2.00607655]
# FWHM: (175,) → [1.54799806e+08 1.58275600e+08 1.50955081e+08 1.64792415e+08
#  1.63294920e+08]
# Gam_tot: (175,) → [89341716.5720993  90861816.68499056 85002913.03275909 95212661.9386006
#  94183029.81320918]
# Fluo: (175,) → [77863.8364458  79093.52511789 83333.01141986 77609.18199536
#  78015.95479158]

# %%
Snew_temp2 = Fluo_temp2/Rinfty2/(1-Fluo_temp2/Rinfty2)
#Snew_temp2 = S_temp2


# Compute Cross_AS
Cross_temp_new2 = Snew_temp2 * Gam_tot_temp2/I_temp2 #*(1+Snew_temp)**.5
Cross_temp_new2 = Cross_temp_new2 / np.amax(Cross_temp_new2)

# Avoid zero or negative values for log normalization
I_postemp2 = np.clip(I_temp2, np.min(I_temp2[I_temp2 > 0]), None)

plt.figure(figsize=(6, 4))

# Scatter plot with log-scale color normalization
sctemp = plt.scatter(
    T_temp2, Cross_temp_new2,
    c=I_postemp2,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_postemp2), vmax=np.max(I_postemp2)),
    s=60,
    edgecolor='k',
    label="Cross_AS vs T"
)


# --- First dataset (temp)
#Snew_temp = Fluo_temp / Rinfty / (1 - Fluo_temp / Rinfty)
Cross_temp_new1 = S_temp1 * Gam_temp1 / I_temp1
Cross_temp_new1 = Cross_temp_new1 / np.amax(Cross_temp_new1)
I_postemp1 = np.clip(I_temp1, np.min(I_temp1[I_temp1 > 0]), None)


# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp1), np.min(I_pos))
vmax = max(np.max(I_postemp1), np.max(I_pos))
norm = LogNorm(vmin=vmin, vmax=vmax)


# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    T_temp1, Cross_temp_new1,
    c=I_postemp1,
    cmap='viridis',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="Cross_temp"
)



# Add colorbar
cbar = plt.colorbar(sctemp)
cbar.set_label("Intensity I (log scale)")

plt.xlabel("Temperature T")
plt.ylabel("Cross_temp (normalized)")
#plt.yscale('log')
#plt.ylim(0,0.3)

plt.tight_layout()
plt.show()

# %%
plt.plot(T_temp1, FWHM_temp1, marker='o', linestyle='none')
plt.plot(T_temp1, Gam_temp1, marker='o', linestyle='none')
plt.plot(T_temp2, Gam_tot_temp2, marker='o', linestyle='none')


plt.yscale('log')

# %%
import numpy as np
from scipy.interpolate import interp1d

# Your data: numpy arrays
# T_temp : array of T values
# Gam_temp : array of Gamma(T) values

# 1. Sort data by T (interp1d requires increasing x)
idx = np.argsort(T_temp1)
T_sorted1 = T_temp1[idx]
Gam_sorted1 = Gam_temp1[idx]

# 2. Interpolating Gamma(T)
Gamma_of_T1 = interp1d(
    T_sorted1,
    Gam_sorted1,
    kind='cubic',          # or 'linear' if you prefer
    bounds_error=False,    # avoids error outside data range
    fill_value="extrapolate"
)

# 3. (Optional but recommended) Check monotonicity of Gamma(T)
dGam1 = np.diff(Gam_sorted1)
is_increasing = np.all(dGam1 > 0)
is_decreasing = np.all(dGam1 < 0)

if not (is_increasing or is_decreasing):
    print("Warning: Gamma(T) is not monotonic -> T(Gamma) will not be single-valued.")

# 4. Build the inverse interpolant T(Gamma)
#    Here we just swap x and y: x = Gamma, y = T
T_of_Gamma1 = interp1d(
    Gam_sorted1,
    T_sorted1,
    kind='cubic',
    bounds_error=False,
    fill_value="extrapolate"
)
# Out:
# Warning: Gamma(T) is not monotonic -> T(Gamma) will not be single-valued.

# %%
T_pow1 = T_of_Gamma1(Gam_pow)

# %%
# %%
# Combined plot of Cross_temp_new and Cross_AS (single panel, shared log-scale colormap)
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

# --- First dataset (temp)
#Snew_temp = Fluo_temp / Rinfty / (1 - Fluo_temp / Rinfty)
Cross_temp_new1 = S_temp1 * Gam_temp1 / I_temp1
Cross_temp_new1 = Cross_temp_new1 / np.amax(Cross_temp_new1)
I_postemp1 = np.clip(I_temp1, np.min(I_temp1[I_temp1 > 0]), None)

# --- Second dataset (AS)
Cross_AS = (S_pow / I_pow * Gam_pow )
Cross_AS = Cross_AS / np.amax(Cross_AS)
I_pos = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)

# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp1), np.min(I_pos))
vmax = max(np.max(I_postemp1), np.max(I_pos))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    T_temp1, Cross_temp_new1,
    c=I_postemp1,
    cmap='viridis',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="Cross_temp"
)

sc2 = plt.scatter(
    T_pow1, Cross_AS,
    c=I_pos,
    cmap='viridis',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="Cross_AS"
)

# --- Colorbar and labels
cbar = plt.colorbar(sc1)
cbar.set_label("Intensity I (log scale)")

plt.xlabel("Temperature T")
plt.ylabel("Debye-Waller")
#plt.yscale('log') 
#plt.xscale('log') 
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(np.amin(T_pow1))
# Out:
# -1.4230454260495102

# %%
# --- First dataset (temp)
Snew_temp1 = Fluo_temp1 / Rinfty / (1 - Fluo_temp1 / Rinfty)
Cross_temp_new1 = Snew_temp1 * Gam_temp1 / I_temp1
Cross_temp_new1 = Cross_temp_new1 / np.amax(Cross_temp_new1)
I_postemp1 = np.clip(I_temp1, np.min(I_temp1[I_temp1 > 0]), None)

# --- Second dataset (AS)
Cross_AS = (S_pow / I_pow * Gam_pow )
Cross_AS = Cross_AS / np.amax(Cross_AS)
I_pos = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)

# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp1), np.min(I_pos))
vmax = max(np.max(I_postemp1), np.max(I_pos))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    T_temp1, Gam_temp1,
    c=I_postemp1,
    cmap='viridis',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="Cross_temp"
)

sc2 = plt.scatter(
    T_pow1, Gam_pow,
    c=I_pos,
    cmap='viridis',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="Cross_AS"
)

# --- Colorbar and labels
cbar = plt.colorbar(sc1)
cbar.set_label("Intensity I (log scale)")

plt.xlabel("Temperature T")
plt.ylabel("FWHM")
#plt.yscale('log') 
#plt.xscale('log') 
plt.xlim(0,40)
#plt.ylim(0,1e10)
plt.legend()
plt.tight_layout()
plt.show()

# %%
T_pow2 = T_of_Gamma1(Gam_pow2)

# %%
# --- First dataset (temp)
#Snew_temp = Fluo_temp / Rinfty / (1 - Fluo_temp / Rinfty)
Cross_temp_new1 = S_pow2 * Gam_pow2 / I_pow2
Cross_temp_new1 = Cross_temp_new1 / np.amax(Cross_temp_new1)
I_postemp1 = np.clip(I_pow2, np.min(I_pow2[I_pow2 > 0]), None)

# --- Second dataset (AS)
Cross_AS = (S_pow / I_pow * Gam_pow )
Cross_AS = Cross_AS / np.amax(Cross_AS)
I_pos = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)

# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp1), np.min(I_pos))
vmax = max(np.max(I_postemp1), np.max(I_pos))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    T_pow2, Cross_temp_new1/6,
    c=I_postemp1,
    cmap='winter',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="old ds"
)

sc2 = plt.scatter(
    T_pow1, Cross_AS,
    c=I_pos,
    cmap='hot',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="new ds"
)



"""sctemp = plt.scatter(
    T_temp2, Cross_temp_new2/10,
    c=I_postemp2,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_postemp2), vmax=np.max(I_postemp2)),
    s=20,
    edgecolor='k',
    marker='^',
    label="Cross_AS vs T"
)"""

# --- Colorbar and labels
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Intensity I (log scale)")

cbar2 = plt.colorbar(sc2)
cbar2.set_label("Intensity I (log scale)")

plt.xlabel("Temperature T")
plt.ylabel("Debye-Waller")
#plt.ylim(0,0.4)
plt.yscale('log') 
#plt.xscale('log') 
plt.legend()
plt.tight_layout()
plt.show()

# %%
I_postemp2 = np.clip(I_pow2, np.min(I_pow2[I_pow2 > 0]), None)
I_postemp1 = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)

logP1 = np.log10(I_pow)
logP2 = np.log10(I_pow2)


logT1 = np.log10(np.abs(T_pow1-2.7))
logT2 = np.log10(np.abs(T_pow2-5))
grad_logT1 = np.gradient( np.log(np.abs(T_pow1-3.7)) , I_postemp1)
grad_logT2 = np.gradient( np.log(np.abs(T_pow2-3.7)) , I_postemp2)

print(logT1, logT2)
# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp2), np.min(I_postemp1))
vmax = max(np.max(I_postemp2), np.max(I_postemp1))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    logP2, logT2,
    c=I_postemp2,
    cmap='winter',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="old ds"
)

sc2 = plt.scatter(
    logP1, logT1,
    c=I_postemp1,
    cmap='hot',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="new ds"
)

plt.plot(logP1+1., .25*logP1)
plt.plot(logP1+2.2, .5*logP1)


# --- Colorbar and labels
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Intensity I (log scale)")

cbar2 = plt.colorbar(sc2)
cbar2.set_label("Intensity I (log scale)")

plt.xlabel("logI")
plt.ylabel("logT")
#plt.ylim(0,0.4)
#plt.yscale('log') 
#plt.xscale('log') 
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [ 0.19555614  0.14334482  0.16997579  0.21492002  0.16829211  0.15990149
#   0.16349539 -0.69689208  0.16425268  0.15431063  0.17743801  0.16190248
#   0.12331519 -0.17381885  0.06370367 -0.02007328  0.12085732  0.03584185
#  -0.30129126  0.1286465   0.30932737  0.61521812  0.13897303 -0.2762899
#   0.18091814  0.36253794  0.19997414  0.39152468  0.15450211  0.30313487
#   0.41678425  0.1727063   0.35919407  0.33112611  0.43258859  0.40991336
#   0.38191445  0.19135186  0.38655541  0.39517741  0.55679748  0.66509107
#   0.38192197  0.65454938  0.62432775  0.79659748  0.72208893  0.72895642
#   0.76510113  0.80530266  0.74858651  0.89094706  0.88944948  0.8829713
#   0.99570503  1.02548579] [0.09860174 0.0877619  0.07564764 0.12840846 0.10742021 0.08114221
#  0.0783212  0.07803096 0.0777286  0.1180949  0.10710729 0.08044998
#  0.08813077 0.09896842 0.08532218 0.10594206 0.2115321  0.15988294
#  0.14719045 0.2454445  0.16980568 0.19679482 0.34997779 0.27213504
#  0.35760707 0.30562214 0.35832916 0.34331179 0.08912065 0.39281663
#  0.36513069 0.39483797 0.43184819 0.45090212 0.65934752 0.66427358
#  0.72490105 0.80461604 0.82750212 0.81250646 0.95577364 0.95369662
#  0.95909449 1.14974983 1.14771687 1.14651651 1.2817664  1.28923648
#  1.37188394]
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1242: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1243: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1243: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1244: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1244: RuntimeWarning: invalid value encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1250: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1259: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_0
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:1266: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_n

# %%
I_postemp2 = np.clip(I_pow2, np.min(I_pow2[I_pow2 > 0]), None)
I_postemp1 = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)

logP1 = np.log10(I_pow)
logP2 = np.log10(I_pow2)


logT1 = np.log10(np.abs(T_pow1-2.7))
logT2 = np.log10(np.abs(T_pow2-5))
grad_logT1 = np.gradient( np.log(np.abs(T_pow1-3.7)) , I_postemp1)
grad_logT2 = np.gradient( np.log(np.abs(T_pow2-3.7)) , I_postemp2)

print(logT1, logT2)
# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp2), np.min(I_postemp1))
vmax = max(np.max(I_postemp2), np.max(I_postemp1))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    T_pow2, I_pow2,
    c=I_postemp2,
    cmap='winter',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="old ds"
)

sc2 = plt.scatter(
    T_pow1, I_pow,
    c=I_postemp1,
    cmap='hot',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="new ds"
)



# --- Colorbar and labels
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Intensity I (log scale)")

cbar2 = plt.colorbar(sc2)
cbar2.set_label("Intensity I (log scale)")

plt.xlabel("T")
plt.ylabel("P")
#plt.ylim(0,0.4)
#plt.yscale('log') 
#plt.xscale('log') 
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [ 0.19555614  0.14334482  0.16997579  0.21492002  0.16829211  0.15990149
#   0.16349539 -0.69689208  0.16425268  0.15431063  0.17743801  0.16190248
#   0.12331519 -0.17381885  0.06370367 -0.02007328  0.12085732  0.03584185
#  -0.30129126  0.1286465   0.30932737  0.61521812  0.13897303 -0.2762899
#   0.18091814  0.36253794  0.19997414  0.39152468  0.15450211  0.30313487
#   0.41678425  0.1727063   0.35919407  0.33112611  0.43258859  0.40991336
#   0.38191445  0.19135186  0.38655541  0.39517741  0.55679748  0.66509107
#   0.38192197  0.65454938  0.62432775  0.79659748  0.72208893  0.72895642
#   0.76510113  0.80530266  0.74858651  0.89094706  0.88944948  0.8829713
#   0.99570503  1.02548579] [0.09860174 0.0877619  0.07564764 0.12840846 0.10742021 0.08114221
#  0.0783212  0.07803096 0.0777286  0.1180949  0.10710729 0.08044998
#  0.08813077 0.09896842 0.08532218 0.10594206 0.2115321  0.15988294
#  0.14719045 0.2454445  0.16980568 0.19679482 0.34997779 0.27213504
#  0.35760707 0.30562214 0.35832916 0.34331179 0.08912065 0.39281663
#  0.36513069 0.39483797 0.43184819 0.45090212 0.65934752 0.66427358
#  0.72490105 0.80461604 0.82750212 0.81250646 0.95577364 0.95369662
#  0.95909449 1.14974983 1.14771687 1.14651651 1.2817664  1.28923648
#  1.37188394]

# %%
filename = "20251215-1505-39_temperature_scan.dat"

data = np.loadtxt(filename, comments="#")

# Inspect shape
print(data.shape)

vT3        = data[:, 0]
vC3       = data[:, 1]
vFWHM3 = data[:, 2]
vA3 = data[:, 3]

delta_om = (vC3-vC3[0])*1e-9
gam = vFWHM3*1e-9

plt.plot(vT3, abs(delta_om), '.-')
plt.plot(vT3, abs(gam), '.-', color='red')
plt.plot(T_temp1, Gam_temp1*1e-9, marker='o', linestyle='none')

plt.xlabel(r'$T$')
plt.ylabel(r'$\omega - GHz$')
plt.yscale('log')
plt.show()
# Out:
# (31, 4)

# %%
font = {
    'family': 'serif',
    'color': 'black',
    'weight': 'normal',
    'size': 16,
}

aaa = .1
prod3 = vFWHM3* aaa*vA3/np.amax(vA3)/(1. - aaa*vA3/np.amax(vA3))
plt.plot(vT3, prod3/np.amax(prod3)  , color='blue', linestyle='none', marker='o')

Snew_temp1 = Fluo_temp1 / Rinfty / (1 - Fluo_temp1 / Rinfty)
Cross_temp_new1 = Snew_temp1 * Gam_temp1 / I_temp1
Cross_temp_new1 = Cross_temp_new1 / np.amax(Cross_temp_new1)
plt.plot(T_temp1, Cross_temp_new1, '.-', color='red', linestyle='none', marker='o')

plt.xlabel(r"$T$ - [K]", fontdict=font)
plt.ylabel(r"DW - (Norm.)", fontdict=font)

leg = plt.legend()
for text in leg.get_texts():
    text.set_fontsize(font['size'])
    text.set_fontname(font['family'])
    text.set_weight(font['weight'])
    text.set_color(font['color'])

plt.xticks(fontsize=font['size'], fontname=font['family'], weight=font['weight'], color=font['color'])
plt.yticks(fontsize=font['size'], fontname=font['family'], weight=font['weight'], color=font['color'])

plt.grid()


plt.xlim(3.7,12)
plt.tight_layout()
# Adjust layout
plt.gcf().set_size_inches(170 / 25.4, 120 / 25.4)

#plt.savefig('DW_T-scan_2newest_dataset.pdf')
plt.show()
# Out:
# /var/folders/y4/dpq6l9fj2kv9z0prq_6_pyy00000gn/T/ipykernel_45714/1572471815.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(T_temp1, Cross_temp_new1, '.-', color='red', linestyle='none', marker='o')
# /var/folders/y4/dpq6l9fj2kv9z0prq_6_pyy00000gn/T/ipykernel_45714/1572471815.py:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   plt.plot(T_temp1, Cross_temp_new1, '.-', color='red', linestyle='none', marker='o')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
delta_om = (vC3-vC3[0])*1e-9
gam = vFWHM3*1e-9

plt.plot(vT3,  abs(delta_om) , '.-')
#plt.ylim(-3,10)
plt.grid()
plt.xlabel(r'$T$')
plt.ylabel(r'$\omega - GHz$')
plt.show()

# %%
delta_om = (vC3-vC3[0])*1e-9
gam = vFWHM3*1e-9

plt.plot(vT3,  (np.log(gam*10)) - np.log(abs(delta_om*50)) , '.-')
plt.ylim(-3,3)
plt.grid()
plt.xlabel(r'$T$')
plt.ylabel(r'$\omega - GHz$')
plt.show()
# Out:
# /var/folders/y4/dpq6l9fj2kv9z0prq_6_pyy00000gn/T/ipykernel_45714/208100437.py:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(vT3,  (np.log(gam*10)) - np.log(abs(delta_om*50)) , '.-')

# %%
filename = "20251215-1505-39_temperature_scan.dat"

data = np.loadtxt(filename, comments="#")

# Inspect shape
print(data.shape)

vT3        = data[:, 0]
vC3       = data[:, 1]
vFWHM3 = data[:, 2]
vA3 = data[:, 3]

delta_om = (vC3-vC3[0])*1e-9
gam = vFWHM3*1e-9

plt.plot(vT3, abs(delta_om), '.-')
plt.plot(vT3, abs(gam), '.-', color='red')
plt.plot(T_temp1, Gam_temp1*1e-9, marker='o', linestyle='none')

plt.xlabel(r'$T$')
plt.ylabel(r'$\omega - GHz$')
plt.yscale('log')
plt.show()
# Out:
# (31, 4)

# %%
# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "off_res/20250409-1233-37_power_sweep_plot_8.dat"

data = np.loadtxt(file_path, comments="#", delimiter='\t')


display(data.shape)

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
Pow3_off1       = data[:, 0]
Fluo3_off1       = data[:, 1]
Pow3_off2       = data[:, 2]
Fluo3_off2    = data[:, 3]
Pow3_off3 = data[:, 4]
Fluo3_off3    = data[:, 5]

# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("P1:", Pow3_off1.shape, "→", Pow3_off1[:5])
print("F1:", Fluo3_off1.shape, "→", Fluo3_off1[:5])
print("P2:", Pow3_off2.shape, "→", Pow3_off2[:5])
print("F2:", Fluo3_off2.shape, "→", Fluo3_off2[:5])
print("P3:", Pow3_off3.shape, "→", Pow3_off3[:5])
print("F3:", Fluo3_off3.shape, "→", Fluo3_off3[:5])

plt.plot(Pow3_off1, Fluo3_off1, marker='o', linestyle='none')

NA0 = 0.7
waist0 = 767*1e-7/(np.pi*NA0)
setup_eff0 = 3./7.
conversion_fact = 2*setup_eff0/(np.pi*waist0**2)

I_off1 = conversion_fact * Pow3_off1
I_off2 = conversion_fact * Pow3_off2
I_off3 = conversion_fact * Pow3_off3
# Out:
# (2999, 6)
# P1: (2999,) → [7.58232591e-06 7.58189062e-06 7.58083360e-06 7.57761028e-06
#  7.57277794e-06]
# F1: (2999,) → [63900. 64800. 67400. 65700. 65650.]
# P2: (2999,) → [7.58232591e-06 7.58189062e-06 7.58083360e-06 7.57761028e-06
#  7.57277794e-06]
# F2: (2999,) → [0. 0. 0. 0. 0.]
# P3: (2999,) → [7.58232591e-06 7.58189062e-06 7.58083360e-06 7.57761028e-06
#  7.57277794e-06]
# F3: (2999,) → [ 0.01017443  0.00791996 -0.00914957 -0.01140404 -0.00560684]

# %%
# %%
# Jupyter Notebook cell 2 — Load the CSV file
# Update the path if needed
file_path = "off_res/20250409-1322-38_power_sweep_plot_3.dat"

data = np.loadtxt(file_path, comments="#", delimiter='\t')


display(data.shape)

# %%
# Jupyter Notebook cell 3 — Extract columns into NumPy arrays
Pow3_off4       = data[:, 0]
Fluo3_off4       = data[:, 1]
Pow3_off5       = data[:, 2]
Fluo3_off5    = data[:, 3]
Pow3_off6 = data[:, 4]
Fluo3_off6    = data[:, 5]

# %%
# Jupyter Notebook cell 4 — Check the extracted arrays
print("P1:", Pow3_off4.shape, "→", Pow3_off4[:5])
print("F1:", Fluo3_off4.shape, "→", Fluo3_off4[:5])
print("P2:", Pow3_off5.shape, "→", Pow3_off5[:5])
print("F2:", Fluo3_off5.shape, "→", Fluo3_off5[:5])
print("P3:", Pow3_off6.shape, "→", Pow3_off6[:5])
print("F3:", Fluo3_off6.shape, "→", Fluo3_off6[:5])

plt.plot(Pow3_off4, Fluo3_off4, marker='o', linestyle='none')


NA0 = 0.7
waist0 = 767*1e-7/(np.pi*NA0)
setup_eff0 = 3./7.
conversion_fact = 2*setup_eff0/(np.pi*waist0**2)

I_off4 = conversion_fact * Pow3_off4
I_off5 = conversion_fact * Pow3_off5
I_off6 = conversion_fact * Pow3_off6
# Out:
# (2997, 6)
# P1: (2997,) → [3.78861805e-05 3.36962896e-05 2.89112332e-05 2.68839934e-05
#  2.49517672e-05]
# F1: (2997,) → [139000. 124850.  21300.  18950.  16750.]
# P2: (2997,) → [3.78861805e-05 3.36962896e-05 2.89112332e-05 2.68839934e-05
#  2.49517672e-05]
# F2: (2997,) → [0. 0. 0. 0. 0.]
# P3: (2997,) → [3.78861805e-05 3.36962896e-05 2.89112332e-05 2.68839934e-05
#  2.49517672e-05]
# F3: (2997,) → [1.14803666 1.14513806 0.07265536 0.06138303 0.05751823]

# %%
DW2 = S_pow2 * Gam_pow2 / I_pow2 * Gam_pow2
DW2 = DW2 / np.amax(DW2)

DW1 = S_pow / I_pow * Gam_pow
DW1 = DW1 / np.amax(DW1)

S3 = Fluo3_off1/np.amax(Fluo3_off1) / (1.-.7*Fluo3_off1/np.amax(Fluo3_off1)) 
DW3 = S3 / I_off1 
DW3 = DW3 / np.amax(DW3)

S4 = Fluo3_off4/np.amax(Fluo3_off4) / (1.-.7*Fluo3_off4/np.amax(Fluo3_off4)) 
DW4 = S4 / I_off4
DW4 = DW4 / np.amax(DW4)

# %%
DW2 = S_pow2 / I_pow2 * Gam_pow2**2
DW2 = DW2 / np.amax(DW2)

DW1 = S_pow / I_pow * Gam_pow**2
DW1 = DW1 / np.amax(DW1)

S3 = Fluo3_off1/np.amax(Fluo3_off1) / (1.-.7*Fluo3_off1/np.amax(Fluo3_off1)) 
DW3 = S3 / I_off1 
DW3 = DW3 / np.amax(DW3)

S4 = Fluo3_off4/np.amax(Fluo3_off4) / (1.-.7*Fluo3_off4/np.amax(Fluo3_off4)) 
DW4 = S4 / I_off4
DW4 = DW4 / np.amax(DW4)



# Compute Cross_AS
Cross_AS = Fluo_pow / I_pow #* Gam_pow / 40e6
Cross_AS = Cross_AS / np.amax(Cross_AS)

# Avoid zero or negative values for log normalization
I_pos = np.clip(Gam_pow, np.min(Gam_pow[Gam_pow > 0]), None)

plt.figure(figsize=(6, 4))

# Compute Cross_AS
Cross_AS2 = Fluo_pow2 / I_pow2 #* Gam_pow2 / 40e6
Cross_AS2 = Cross_AS2 / np.amax(Cross_AS2)
# Avoid zero or negative values for log normalization
I_pos2 = np.clip(Gam_pow2, np.min(Gam_pow2[Gam_pow2 > 0]), None)

Cross_off = Fluo3_off1 / I_off1
Cross_off = Cross_off/np.amax(Cross_off)

sc2 = plt.scatter(
    I_pow2, DW2,
    c=I_pos2,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_pos2), vmax=np.max(I_pos2)),
    s=60,
    edgecolor='k',
    marker='o',
    label="Old"
)

# Scatter plot with log-scale color normalization
sc = plt.scatter(
    I_pow, DW1,
    c=I_pos,
    cmap='viridis',
    norm=LogNorm(vmin=np.min(I_pos), vmax=np.max(I_pos)),
    s=60,
    edgecolor='k',
    marker='s',
    label="New"
)

"""sc3 = plt.scatter(
    I_off1, DW3,
    c=I_off1,
    cmap='hot',
    norm=LogNorm(vmin=np.min(I_off1), vmax=np.max(I_off1)),
    s=60,
    edgecolor='k',
    marker='^',
    label="OffRes"
)"""

"""Isat_off = 1e0
Soff =  DW2**2 * I_pow2/Isat_off
thF = Soff/(1+Soff)
plt.plot(I_pow2*100, thF/np.amax(thF), marker='o', color='red', linestyle='none')

Isat_off1 = 1e1
Soff1 =  DW1**2 * I_pow/Isat_off1
thF1 = Soff1/(1+Soff1)
plt.plot(I_pow*100, 1.5*thF1/np.amax(thF1), marker='o', color='blue', linestyle='none')"""



# Add colorbar
cbar = plt.colorbar(sc)
cbar.set_label("Intensity I (log scale)")
plt.ylim(1e-4,1)
#plt.yscale('log')
plt.xlabel("Intensity")
plt.ylabel("DW")
plt.xscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --- First dataset (temp)
#Snew_temp = Fluo_temp / Rinfty / (1 - Fluo_temp / Rinfty)
Cross_temp_new1 = S_pow2
Cross_temp_new1 = Cross_temp_new1 #/ np.amax(Cross_temp_new1)
I_postemp1 = np.clip(I_pow2, np.min(I_pow2[I_pow2 > 0]), None)

# --- Second dataset (AS)
S_pow_eff = Fluo_pow/np.amax(Fluo_pow)/(1. - .99*Fluo_pow/np.amax(Fluo_pow))
Cross_AS = (S_pow * Gam_pow**(2*0) )
Cross_AS = Cross_AS #/ np.amax(Cross_AS)
I_pos = np.clip(I_pow, np.min(I_pow[I_pow > 0]), None)


S3 = Fluo3_off1/np.amax(Fluo3_off1) / (1.-.7*Fluo3_off1/np.amax(Fluo3_off1)) 
DW3 = S3 #/ I_off1
DW3 = DW3 #/ np.amax(DW3)

S4 = Fluo3_off4/np.amax(Fluo3_off4) / (1.-.1*Fluo3_off4/np.amax(Fluo3_off4)) 
DW4 = S4 #/ I_off4
DW4 = DW4 #/ np.amax(DW4)




# --- Determine common color scale for both datasets
vmin = min(np.min(I_postemp1), np.min(I_pos))
vmax = max(np.max(I_postemp1), np.max(I_pos))
norm = LogNorm(vmin=vmin, vmax=vmax)

# --- Create combined figure
plt.figure(figsize=(6, 4))


sc3 = plt.scatter(
    I_off1, DW3*1.,
    s=30,
    color='red',
    edgecolor='k',
    marker='^',
    label="offRes"
)

sc3 = plt.scatter(
    I_off4, DW4*1.,
    s=30,
    color='green',
    edgecolor='k',
    marker='<',
    label="offRes2"
)

# Plot both datasets with same colormap and normalization
sc1 = plt.scatter(
    I_pow2, Cross_temp_new1,
    c=I_postemp1,
    cmap='winter',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='o',
    label="old ds"
)

sc2 = plt.scatter(
    I_pow, Cross_AS*1,
    c=I_pos,
    cmap='hot',
    norm=norm,
    s=60,
    edgecolor='k',
    marker='s',
    label="new ds"
)


# --- Colorbar and labels
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Intensity I (log scale)")

cbar2 = plt.colorbar(sc2)
cbar2.set_label("Intensity I (log scale)")

plt.xlabel(r"$I$ - W/cm$^2$")
plt.ylabel(r"$S/I$ - a.u. [normalized]")
plt.xlim(1e-1,1e7)
plt.ylim(1e-3,1e2)
plt.yscale('log') 
plt.xscale('log') 
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
